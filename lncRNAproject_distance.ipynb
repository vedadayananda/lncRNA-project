# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.ticker as mticker
from IPython.display import Image

# %%
df1 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-02-0055/TCGA-02-0055 Data/FPKM-UQ_TCGA-02-0055.txt', sep='\t', header=None)
df2 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-19-2619/TCGA-19-2619 Data/FPKM-UQ_ TCGA-19-2619.txt', sep='\t', header=None)
df3 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-16-1045/TCGA-16-1045 Data/FPKM-UQ_ TCGA-16-1045.txt', sep='\t', header=None)
df4 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-06-0178/TCGA-06-0178 Data/FPKM-UQ_ TCGA-06-0178.txt', sep='\t', header=None)
df5 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-14-1823/TCGA-14-1823 Data/FPKM-UQ_ TCGA-14-1823.txt', sep='\t', header=None)
df6 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-06-0744/TCGA-06-0744 Data/FPKM-UQ_ TCGA-06-0744.txt', sep='\t', header=None)
df7 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-26-5132/TCGA-26-5132 Data/FPKM-UQ_ TCGA-26-5132.txt', sep='\t', header=None)
df8 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-26-1442/TCGA-26-1442 Data/FPKM-UQ_ TCGA-26-1442.txt', sep='\t', header=None)
df9 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-27-2526/TCGA-27-2526 Data/FPKM-UQ_ TCGA-27-2526.txt', sep='\t', header=None)
df10 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-15-1444/TCGA-15-1444 Data/FPKM-UQ_ TCGA-15-1444.txt', sep='\t', header=None)
df11 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/gProfiler_hsapiens_11-14-2020_7-58-50 PM.csv')
df12 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-06-0675 Normal/TCGA-06-0675 Normal Data/FPKM-UQ_FPKM-UQ_TCGA-06-0675_Normal.txt', sep='\t', header=None)
df13 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-06-0678 Normal/TCGA-06-0678 Normal Data/FPKM-UQ_TCGA-06-0678_Normal.txt', sep='\t', header=None)
df14 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-06-0681 Normal/TCGA-06-0681 Normal Data/FPKM-UQ_TCGA-06-0681_Normal.txt', sep='\t', header=None)
df15 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-06-0680 Normal/TCGA-06-0680 Normal Data/FPKM-UQ_TCGA-06-0680_Normal.txt', sep='\t', header=None)
df16 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/TCGA-06-AABW Normal/TCGA-06-AABW Normal Data/FPKM-UQ_TCGA-06-AABW_Normal.txt', sep='\t', header=None)

# %%
df1.columns =['Ensembl Gene ID','TCGA-02-0055']

# %%
df2.columns =['Ensembl Gene ID','TCGA-19-2619']

# %%
df3.columns =['Ensembl Gene ID','TCGA-16-1045']

# %%
df4.columns =['Ensembl Gene ID','TCGA-06-0178']

# %%
df5.columns =['Ensembl Gene ID','TCGA-14-1823']

# %%
df6.columns =['Ensembl Gene ID','TCGA-06-0744']

# %%
df7.columns =['Ensembl Gene ID','TCGA-26-5132']

# %%
df8.columns =['Ensembl Gene ID','TCGA-26-1442']

# %%
df9.columns =['Ensembl Gene ID','TCGA-27-2526']

# %%
df10.columns =['Ensembl Gene ID','TCGA-15-1444']

# %%
df12.columns =['Ensembl Gene ID','TCGA-06-0675']

# %%
df13.columns =['Ensembl Gene ID','TCGA-06-0678']

# %%
df14.columns =['Ensembl Gene ID','TCGA-06-0681']

# %%
df15.columns =['Ensembl Gene ID','TCGA-06-0680']

# %%
df16.columns =['Ensembl Gene ID','TCGA-06-AABW']

# %%
# Formatting Ensembl Gene IDs to paste into gProfiler
names = df1['Ensembl Gene ID'].values
rows_list = []
for i in names:
    rows_list.append(i.split('.')[0])
df_names = pd.DataFrame(rows_list)

# %%
df_names.to_csv('/Users/vedadayananda/Downloads/lncRNA Project/names.txt',sep=' ', index=False, header=False)

# %%
#gProfiler results
df11.columns =['Initial Alias','Converted Alias','Name','Description','Namespace']
df11.head()
# Out:
#      Initial Alias  Converted Alias        Name  \
# 0  ENSG00000242268  ENSG00000242268   LINC02082
# 1  ENSG00000270112  ENSG00000270112  AC090241.2
# 2  ENSG00000167578  ENSG00000167578       RAB4B
# 3  ENSG00000273842             None        None
# 4  ENSG00000078237  ENSG00000078237       TIGAR
#
#                                          Description          Namespace
# 0  long intergenic non-protein coding RNA 2082 [S...  ARRAYEXPRESS,ENSG
# 1             novel transcript, antisense to ST8SIA5  ARRAYEXPRESS,ENSG
# 2  RAB4B, member RAS oncogene family [Source:HGNC...  ARRAYEXPRESS,ENSG
# 3                                               None                NaN
# 4  TP53 induced glycolysis regulatory phosphatase...  ARRAYEXPRESS,ENSG

# %%
frames = [df1['Ensembl Gene ID'], df11['Name'], df1['TCGA-02-0055'], df2['TCGA-19-2619'], df3['TCGA-16-1045'], df4['TCGA-06-0178'], df5['TCGA-14-1823'], df6['TCGA-06-0744'], df7['TCGA-26-5132'], df8['TCGA-26-1442'], df9['TCGA-27-2526'], df10['TCGA-15-1444']]
tumor = pd.concat(frames, axis = 1)
tumor.head()
# Out:
#       Ensembl Gene ID        Name   TCGA-02-0055   TCGA-19-2619  \
# 0   ENSG00000242268.2   LINC02082       0.000000   15000.616097
# 1   ENSG00000270112.3  AC090241.2     401.493596    8697.208040
# 2  ENSG00000167578.15       RAB4B   93146.565338   84248.171539
# 3   ENSG00000273842.1        None       0.000000       0.000000
# 4   ENSG00000078237.5       TIGAR  130993.660824  109720.493335
#
#     TCGA-16-1045   TCGA-06-0178   TCGA-14-1823   TCGA-06-0744   TCGA-26-5132  \
# 0    1615.427331   17935.327320   32198.908759   16869.777618   11800.490963
# 1    5155.350462     878.323632     698.078257     975.306341     172.353221
# 2   76618.934600  276451.489233  169847.812459  215876.663818  102485.046774
# 3       0.000000       0.000000       0.000000       0.000000       0.000000
# 4  117427.085297  303540.521421  456345.371914  113416.190161  188610.211507
#
#     TCGA-26-1442   TCGA-27-2526   TCGA-15-1444
# 0   51337.182615       0.000000    9496.951742
# ...

# %%
tumor.to_csv('/Users/vedadayananda/Downloads/lncRNA Project/tumor10.csv')

# %%
#search gProfiler results for lncRNAs
df11[df11['Name'].str.contains('LINC')]
# Out:
#          Initial Alias  Converted Alias       Name  \
# 0      ENSG00000242268  ENSG00000242268  LINC02082
# 18     ENSG00000240423  ENSG00000240423  LINC00636
# 26     ENSG00000269416  ENSG00000269416  LINC01224
# 50     ENSG00000258630  ENSG00000258630  LINC02292
# 53     ENSG00000225269  ENSG00000225269  LINC00705
# ...                ...              ...        ...
# 60372  ENSG00000258770  ENSG00000258770  LINC02330
# 60420  ENSG00000255727  ENSG00000255727  LINC01489
# 60423  ENSG00000248869  ENSG00000248869  LINC02511
# 60424  ENSG00000237803  ENSG00000237803  LINC00211
# 60470  ENSG00000203729  ENSG00000203729  LINC00272
#
#                                              Description          Namespace
# 0      long intergenic non-protein coding RNA 2082 [S...  ARRAYEXPRESS,ENSG
# 18     long intergenic non-protein coding RNA 636 [So...  ARRAYEXPRESS,ENSG
# 26     long intergenic non-protein coding RNA 1224 [S...  ARRAYEXPRESS,ENSG
# ...

# %%
#search tumor samples for lncRNAs
tumor[tumor['Name'].str.contains('LINC')]
# Out:
#          Ensembl Gene ID       Name  TCGA-02-0055  TCGA-19-2619  TCGA-16-1045  \
# 0      ENSG00000242268.2  LINC02082      0.000000  15000.616097   1615.427331
# 18     ENSG00000240423.1  LINC00636   1219.012697   1504.639103   4536.999229
# 26     ENSG00000269416.4  LINC01224    934.970904  40622.334159   1739.917180
# 50     ENSG00000258630.1  LINC02292      0.000000      0.000000      0.000000
# 53     ENSG00000225269.2  LINC00705    294.332770    435.957324    657.279888
# ...                  ...        ...           ...           ...           ...
# 60372  ENSG00000258770.1  LINC02330    925.424654      0.000000      0.000000
# 60420  ENSG00000255727.1  LINC01489    848.943278    628.715315    947.895376
# 60423  ENSG00000248869.4  LINC02511    265.431878      0.000000      0.000000
# 60424  ENSG00000237803.4  LINC00211    989.615960      0.000000    883.971796
# 60470  ENSG00000203729.7  LINC00272      0.000000    514.017250      0.000000
#
# ...

# %%
frames2 = [df12['Ensembl Gene ID'], df11['Name'], df12['TCGA-06-0675'], df13['TCGA-06-0678'], df14['TCGA-06-0681'], df15['TCGA-06-0680'], df16['TCGA-06-AABW']]
normal = pd.concat(frames2, axis = 1)
normal.head()
# Out:
#       Ensembl Gene ID        Name   TCGA-06-0675   TCGA-06-0678  \
# 0   ENSG00000242268.2   LINC02082    1260.358572    6520.605112
# 1   ENSG00000270112.3  AC090241.2   11454.558412   12937.991734
# 2  ENSG00000167578.15       RAB4B  135125.997321  134996.566289
# 3   ENSG00000273842.1        None       0.000000       0.000000
# 4   ENSG00000078237.5       TIGAR   70599.675419   93572.732508
#
#     TCGA-06-0681   TCGA-06-0680   TCGA-06-AABW
# 0    4235.032186    3327.048908    2930.075578
# 1   10157.503423   12848.941078    3659.015623
# 2  169988.312485  122900.245800  295117.480106
# 3       0.000000       0.000000       0.000000
# 4   68631.897719   65768.738881   67957.301997

# %%
#search normal samples for lncRNAs
normal[normal['Name'].str.contains('LINC')]
# Out:
#          Ensembl Gene ID       Name  TCGA-06-0675  TCGA-06-0678  TCGA-06-0681  \
# 0      ENSG00000242268.2  LINC02082   1260.358572   6520.605112   4235.032186
# 18     ENSG00000240423.1  LINC00636   3539.772888   2930.145335   3398.364435
# 26     ENSG00000269416.4  LINC01224    950.240003    983.234448   1303.256264
# 50     ENSG00000258630.1  LINC02292      0.000000      0.000000      0.000000
# 53     ENSG00000225269.2  LINC00705      0.000000      0.000000      0.000000
# ...                  ...        ...           ...           ...           ...
# 60372  ENSG00000258770.1  LINC02330   2418.525908   5005.005005   1547.939692
# 60420  ENSG00000255727.1  LINC01489      0.000000      0.000000    710.005396
# 60423  ENSG00000248869.4  LINC02511      0.000000      0.000000      0.000000
# 60424  ENSG00000237803.4  LINC00211      0.000000    178.405766      0.000000
# 60470  ENSG00000203729.7  LINC00272      0.000000      0.000000      0.000000
#
# ...

# %%
normal.to_csv('/Users/vedadayananda/Downloads/lncRNA Project/normal.csv')

# %%
normal2 = normal.copy()
normal2['Average'] = (normal2['TCGA-06-0675'] + normal2['TCGA-06-0678'] + normal2['TCGA-06-0681'] + normal2['TCGA-06-0680'] + normal2['TCGA-06-AABW'])/5
normal2.head()
# Out:
#       Ensembl Gene ID        Name   TCGA-06-0675   TCGA-06-0678  \
# 0   ENSG00000242268.2   LINC02082    1260.358572    6520.605112
# 1   ENSG00000270112.3  AC090241.2   11454.558412   12937.991734
# 2  ENSG00000167578.15       RAB4B  135125.997321  134996.566289
# 3   ENSG00000273842.1        None       0.000000       0.000000
# 4   ENSG00000078237.5       TIGAR   70599.675419   93572.732508
#
#     TCGA-06-0681   TCGA-06-0680   TCGA-06-AABW        Average
# 0    4235.032186    3327.048908    2930.075578    3654.624071
# 1   10157.503423   12848.941078    3659.015623   10211.602054
# 2  169988.312485  122900.245800  295117.480106  171625.720400
# 3       0.000000       0.000000       0.000000       0.000000
# 4   68631.897719   65768.738881   67957.301997   73306.069305

# %%
tumor2 = tumor.copy()
tumor2['Average'] = (tumor2['TCGA-02-0055'] + tumor2['TCGA-19-2619'] + tumor2 ['TCGA-16-1045'] + tumor2['TCGA-06-0178'] + tumor2['TCGA-14-1823'] + tumor2['TCGA-06-0744'] + tumor2['TCGA-26-5132'] + tumor2['TCGA-26-1442'] + tumor2['TCGA-27-2526'] + tumor2['TCGA-15-1444'])/10
tumor2.head()
# Out:
#       Ensembl Gene ID        Name   TCGA-02-0055   TCGA-19-2619  \
# 0   ENSG00000242268.2   LINC02082       0.000000   15000.616097
# 1   ENSG00000270112.3  AC090241.2     401.493596    8697.208040
# 2  ENSG00000167578.15       RAB4B   93146.565338   84248.171539
# 3   ENSG00000273842.1        None       0.000000       0.000000
# 4   ENSG00000078237.5       TIGAR  130993.660824  109720.493335
#
#     TCGA-16-1045   TCGA-06-0178   TCGA-14-1823   TCGA-06-0744   TCGA-26-5132  \
# 0    1615.427331   17935.327320   32198.908759   16869.777618   11800.490963
# 1    5155.350462     878.323632     698.078257     975.306341     172.353221
# 2   76618.934600  276451.489233  169847.812459  215876.663818  102485.046774
# 3       0.000000       0.000000       0.000000       0.000000       0.000000
# 4  117427.085297  303540.521421  456345.371914  113416.190161  188610.211507
#
#     TCGA-26-1442   TCGA-27-2526   TCGA-15-1444        Average
# ...

# %%
#search normal samples for PTEN
normal.loc[normal['Name'] == 'PTEN']
# Out:
#          Ensembl Gene ID  Name   TCGA-06-0675   TCGA-06-0678   TCGA-06-0681  \
# 40589  ENSG00000171862.8  PTEN  227320.074722  189559.950965  181515.905331
#
#         TCGA-06-0680  TCGA-06-AABW
# 40589  212751.017167  95615.637268

# %%
#search tumor samples for PTEN
tumor.loc[tumor['Name'] == 'PTEN']
# Out:
#          Ensembl Gene ID  Name   TCGA-02-0055   TCGA-19-2619   TCGA-16-1045  \
# 40589  ENSG00000171862.8  PTEN  183036.014318  125540.625423  179193.028978
#
#        TCGA-06-0178   TCGA-14-1823  TCGA-06-0744  TCGA-26-5132  TCGA-26-1442  \
# 40589  82151.640753  110329.131525   82635.31774  93812.033846  151310.21779
#
#        TCGA-27-2526   TCGA-15-1444
# 40589  98450.159127  138508.297119

# %%
frames3 = [df11['Name'], tumor2['Average'], normal2['Average']]
plot = pd.concat(frames3, axis = 1)
plot.columns =['Name','Tumor Average','Normal Average']
plot.head()
# Out:
#          Name  Tumor Average  Normal Average
# 0   LINC02082   15625.468244     3654.624071
# 1  AC090241.2    2182.611638    10211.602054
# 2       RAB4B  145270.315779   171625.720400
# 3        None       0.000000        0.000000
# 4       TIGAR  201397.508295    73306.069305

# %%
df17 = plot.copy()
df17["TN_Ratio"] = plot["Tumor Average"] / plot["Normal Average"]
df17["Log_Tumor"] = np.log(plot["Tumor Average"])
df17["Log_Normal"] = np.log(plot["Normal Average"])
df17["Log_TN_Ratio"] = df17["Log_Tumor"] / df17["Log_Normal"]
df17.head()
# Out:
# /Users/vedadayananda/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#          Name  Tumor Average  Normal Average  TN_Ratio  Log_Tumor  Log_Normal  \
# 0   LINC02082   15625.468244     3654.624071  4.275534   9.656657    8.203749
# 1  AC090241.2    2182.611638    10211.602054  0.213738   7.688277    9.231280
# 2       RAB4B  145270.315779   171625.720400  0.846437  11.886352   12.053071
# 3        None       0.000000        0.000000       NaN       -inf        -inf
# 4       TIGAR  201397.508295    73306.069305  2.747351  12.213036   11.202399
#
#    Log_TN_Ratio
# 0      1.177103
# 1      0.832851
# 2      0.986168
# 3           NaN
# 4      1.090216

# %%
plot.to_csv('/Users/vedadayananda/Downloads/lncRNA Project/plot.csv')

# %%
def figure_presets(
    title,
    x_lab,
    y_lab,
    size=(10, 10),
    title_fontsize=20,
    title_adjustment_factor=1.1,
    axis_label_fontsize=15,
):

    """
    presets for one single figure to look nice
    """

    fig = plt.figure(figsize=size)
    ax = fig.add_subplot(1, 1, 1)
    ax.set_title(title, fontsize=title_fontsize, y=title_adjustment_factor)
    ax.set_xlabel(x_lab, fontsize=axis_label_fontsize)
    ax.set_ylabel(y_lab, fontsize=axis_label_fontsize)
    ax.spines["left"].set_linewidth(3)
    ax.spines["bottom"].set_linewidth(3)
    #removing top and right borders
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.yaxis.set_ticks_position("left")
    ax.xaxis.set_ticks_position("bottom")

# %%
#Expression values for all features
figure_presets(
    title="Expression Values for All Features",
    x_lab="Tumor Expression",
    y_lab="Normal Expression",
)

plt.scatter(df17["Tumor Average"], df17["Normal Average"], c="darkblue", alpha=0.5)
plt.ticklabel_format(useOffset=False, style='plain')

class MathTextSciFormatter(mticker.Formatter):
    def __init__(self, fmt="%1.2e"):
        self.fmt = fmt
    def __call__(self, x, pos=None):
        s = self.fmt % x
        decimal_point = '.'
        positive_sign = '+'
        tup = s.split('e')
        significand = tup[0].rstrip(decimal_point)
        sign = tup[1][0].replace(positive_sign, '')
        exponent = tup[1][1:].lstrip('0')
        if exponent:
            exponent = '10^{%s%s}' % (sign, exponent)
        if significand and exponent:
            s =  r'%s{\times}%s' % (significand, exponent)
        else:
            s =  r'%s%s' % (significand, exponent)
        return "${}$".format(s)

# Format with 2 decimal places
plt.gca().yaxis.set_major_formatter(MathTextSciFormatter("%1.2e"))
plt.gca().xaxis.set_major_formatter(MathTextSciFormatter("%1.2e"))

plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)


plt.xlim(0,300000000)
plt.ylim(0,300000000)
# Out:
# (0.0, 300000000.0)

# %%
df18 = df17[df17['Name'].str.contains('LINC')]
df18
# Out:
#             Name  Tumor Average  Normal Average  TN_Ratio  Log_Tumor  \
# 0      LINC02082   15625.468244     3654.624071  4.275534   9.656657
# 18     LINC00636    2380.549286     4598.519060  0.517677   7.775087
# 26     LINC01224   11988.853953     1835.651607  6.531116   9.391733
# 50     LINC02292       0.000000       61.150901  0.000000       -inf
# 53     LINC00705     220.530349        0.000000       inf   5.396035
# ...          ...            ...             ...       ...        ...
# 60372  LINC02330     631.565231     2078.042436  0.303923   6.448201
# 60420  LINC01489     939.584969      574.229175  1.636254   6.845438
# 60423  LINC02511     481.926523      591.314994  0.815008   6.177792
# 60424  LINC00211     342.767059       96.367209  3.556885   5.837051
# 60470  LINC00272      51.401725        0.000000       inf   3.939672
#
#        Log_Normal  Log_TN_Ratio
# 0        8.203749      1.177103
# 18       8.433490      0.921930
# 26       7.515155      1.249706
# ...

# %%
#Expression values for lncRNAs
figure_presets(
    title="Expression Values for lncRNAs",
    x_lab="Tumor Expression",
    y_lab="Normal Expression",
)

plt.scatter(df18["Tumor Average"], df18["Normal Average"], c="darkblue", alpha=0.5)
plt.ticklabel_format(useOffset=False, style='plain')

class MathTextSciFormatter(mticker.Formatter):
    def __init__(self, fmt="%1.2e"):
        self.fmt = fmt
    def __call__(self, x, pos=None):
        s = self.fmt % x
        decimal_point = '.'
        positive_sign = '+'
        tup = s.split('e')
        significand = tup[0].rstrip(decimal_point)
        sign = tup[1][0].replace(positive_sign, '')
        exponent = tup[1][1:].lstrip('0')
        if exponent:
            exponent = '10^{%s%s}' % (sign, exponent)
        if significand and exponent:
            s =  r'%s{\times}%s' % (significand, exponent)
        else:
            s =  r'%s%s' % (significand, exponent)
        return "${}$".format(s)

# Format with 2 decimal places
plt.gca().yaxis.set_major_formatter(MathTextSciFormatter("%1.2e"))
plt.gca().xaxis.set_major_formatter(MathTextSciFormatter("%1.2e"))

plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)

plt.xlim(0,1200000)
plt.ylim(0,1200000)
# Out:
# (0.0, 1200000.0)

# %%
cutoff_ratio = 1.5

df17["Under_Expressed"] = df17["Log_TN_Ratio"] > cutoff_ratio
df17["Over_Expressed"] = df17["Log_TN_Ratio"] < 1 / cutoff_ratio

over_exp = df17.loc[df17["Under_Expressed"] == True]
under_exp = df17.loc[df17["Over_Expressed"] == True]

# %%
under_x = np.arange(3, 17.5)
under_y = under_x * (1 / cutoff_ratio)

over_x = np.arange(3, 12)
over_y = over_x * cutoff_ratio

# %%
#log-transformed for all features

figure_presets(
    title="Relative Expression for All Features",
    x_lab="Log10 (Tumor)",
    y_lab="Log10 (Normal)",
)

plt.scatter(df17["Log_Tumor"], df17["Log_Normal"], c="lightgrey", alpha=0.05, zorder=1)
plt.plot(over_x, over_y, "--", lw=4, c="#F6D55C", zorder=2, alpha=0.5)
plt.plot(under_x, under_y, "--", lw=4, c="#F6D55C", zorder=2, alpha=0.5)
plt.scatter(
    under_exp["Log_Tumor"],
    under_exp["Log_Normal"],
    c="#C21F01",
    alpha=0.3,
    label="Under-expresed in GBM",
    zorder=3,
)
plt.scatter(
    over_exp["Log_Tumor"],
    over_exp["Log_Normal"],
    c="#191970",
    alpha=0.3,
    label="Over-expresed in GBM",
    zorder=3,
)
plt.legend(markerscale=1.5, edgecolor="w", fontsize=14, handletextpad=None)

plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)

plt.xlim(0,20)
plt.ylim(0,20)
# Out:
# (0.0, 20.0)

# %%
cutoff_ratio2 = 1.5

df18["Under_Expressed"] = df18["Log_TN_Ratio"] > cutoff_ratio2
df18["Over_Expressed"] = df18["Log_TN_Ratio"] < 1 / cutoff_ratio2

over_exp2 = df18.loc[df18["Under_Expressed"] == True]
under_exp2 = df18.loc[df18["Over_Expressed"] == True]
# Out:
# <ipython-input-42-000c954f1eaf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18["Under_Expressed"] = df18["Log_TN_Ratio"] > cutoff_ratio2
# <ipython-input-42-000c954f1eaf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df18["Over_Expressed"] = df18["Log_TN_Ratio"] < 1 / cutoff_ratio2

# %%
#log-transformed for lncRNAs
figure_presets(
    title="Relative Expression for lncRNAs",
    x_lab="Log10 (Tumor)",
    y_lab="Log10 (Normal)",
)

plt.scatter(df18["Log_Tumor"], df18["Log_Normal"], c="lightgrey", alpha=0.4, zorder=1)
plt.plot(over_x, over_y, "--", lw=4, c="#F6D55C", zorder=2, alpha=0.5)
plt.plot(under_x, under_y, "--", lw=4, c="#F6D55C", zorder=2, alpha=0.5)
plt.scatter(
    under_exp2["Log_Tumor"],
    under_exp2["Log_Normal"],
    c="#C21F01",
    alpha=0.5,
    label="Under-expresed in GBM",
    zorder=3,
)
plt.scatter(
    over_exp2["Log_Tumor"],
    over_exp2["Log_Normal"],
    c="#191970",
    alpha=0.5,
    label="Over-expresed in GBM",
    zorder=3,
)
plt.legend(markerscale=1.5, edgecolor="w", fontsize=14, handletextpad=None)

plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)

plt.xlim(0,20)
plt.ylim(0,20)
# Out:
# (0.0, 20.0)

# %%
normal.head()
# Out:
#       Ensembl Gene ID        Name   TCGA-06-0675   TCGA-06-0678  \
# 0   ENSG00000242268.2   LINC02082    1260.358572    6520.605112
# 1   ENSG00000270112.3  AC090241.2   11454.558412   12937.991734
# 2  ENSG00000167578.15       RAB4B  135125.997321  134996.566289
# 3   ENSG00000273842.1        None       0.000000       0.000000
# 4   ENSG00000078237.5       TIGAR   70599.675419   93572.732508
#
#     TCGA-06-0681   TCGA-06-0680   TCGA-06-AABW
# 0    4235.032186    3327.048908    2930.075578
# 1   10157.503423   12848.941078    3659.015623
# 2  169988.312485  122900.245800  295117.480106
# 3       0.000000       0.000000       0.000000
# 4   68631.897719   65768.738881   67957.301997

# %%
tumor
# Out:
#           Ensembl Gene ID        Name   TCGA-02-0055   TCGA-19-2619  \
# 0       ENSG00000242268.2   LINC02082       0.000000   15000.616097
# 1       ENSG00000270112.3  AC090241.2     401.493596    8697.208040
# 2      ENSG00000167578.15       RAB4B   93146.565338   84248.171539
# 3       ENSG00000273842.1        None       0.000000       0.000000
# 4       ENSG00000078237.5       TIGAR  130993.660824  109720.493335
# ...                   ...         ...            ...            ...
# 60478  ENSG00000105063.17      PPP6R1  258326.746430  364714.096102
# 60479   ENSG00000231119.2  AL031666.1   33218.601395    2523.202423
# 60480   ENSG00000280861.1        None       0.000000       0.000000
# 60481   ENSG00000123685.7       BATF3  128355.342110   12337.929726
# 60482   ENSG00000181518.3       OR8D4       0.000000       0.000000
#
#         TCGA-16-1045   TCGA-06-0178   TCGA-14-1823   TCGA-06-0744  \
# 0        1615.427331   17935.327320   32198.908759   16869.777618
# ...

# %%
df19 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/HTSeq-Counts/results_sorted_by_pval_adjusted.csv')
df20 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/HTSeq-Counts/deseq2_results.csv')

# %%
df19.columns =['Ensembl Gene ID','baseMean', 'Log2FC', 'lfcSE', 'stat', 'p-val', 'p-val adj']
df19.head()
# Out:
#      Ensembl Gene ID     baseMean    Log2FC     lfcSE       stat  \
# 0  ENSG00000213553.4  1646.793666 -6.383591  0.374046 -17.066346
# 1  ENSG00000181104.6  2963.938005 -4.607920  0.275648 -16.716657
# 2  ENSG00000224861.1   208.653073 -4.792579  0.302110 -15.863674
# 3  ENSG00000198944.5  1555.586207  5.008116  0.318763  15.711106
# 4  ENSG00000169213.6  1350.561444  5.562841  0.364767  15.250387
#
#           p-val     p-val adj
# 0  2.642298e-65  9.699084e-61
# 1  9.912533e-63  1.819297e-58
# 2  1.130812e-56  1.383624e-52
# 3  1.269453e-55  1.164946e-51
# 4  1.636600e-52  1.201494e-48

# %%
df21 = pd.read_csv('/Users/vedadayananda/Downloads/lncRNA Project/HTSeq-Counts/gProfilerHTSeq.csv')
df21
# Out:
#          initial_alias  converted_alias     name  \
# 0      ENSG00000213553  ENSG00000213553  RPLP0P6
# 1      ENSG00000181104  ENSG00000181104      F2R
# 2      ENSG00000224861  ENSG00000224861   YBX1P1
# 3      ENSG00000198944  ENSG00000198944   SOWAHA
# 4      ENSG00000169213  ENSG00000169213    RAB3B
# ...                ...              ...      ...
# 60478  ENSGR0000275287             None     None
# 60479  ENSGR0000276543             None     None
# 60480  ENSGR0000277120             None     None
# 60481  ENSGR0000280767             None     None
# 60482  ENSGR0000281849             None     None
#
#                                              description          namespace
# 0      ribosomal protein lateral stalk subunit P0 pse...  ARRAYEXPRESS,ENSG
# 1      coagulation factor II thrombin receptor [Sourc...  ARRAYEXPRESS,ENSG
# 2      Y-box binding protein 1 pseudogene 1 [Source:H...  ARRAYEXPRESS,ENSG
# ...

# %%
df19['Name'] = df21['name']
#all features

# %%
df19.loc[df19['Name'] == 'PTEN']
# Out:
#          Ensembl Gene ID     baseMean   Log2FC     lfcSE      stat     p-val  \
# 12217  ENSG00000171862.8  3484.470496  0.75128  0.287458  2.613528  0.008961
#
#        p-val adj  Name
# 12217   0.026923  PTEN

# %%
df22 = df19[df19['Name'].str.contains('LINC')]

# %%
df22
#lncRNAs
# Out:
#          Ensembl Gene ID    baseMean     Log2FC     lfcSE       stat  \
# 122    ENSG00000233123.1  172.510434  10.048779  0.980599  10.247588
# 169    ENSG00000248455.4   42.451333   6.082820  0.621323   9.790103
# 203    ENSG00000265313.4   40.004482   8.481965  0.888955   9.541506
# 253    ENSG00000206187.3   29.249152   7.743794  0.837701   9.244100
# 274    ENSG00000261325.1   21.631658   6.226237  0.679233   9.166574
# ...                  ...         ...        ...       ...        ...
# 60158  ENSG00000281248.1    0.000000        NaN       NaN        NaN
# 60258  ENSG00000281477.1    0.000000        NaN       NaN        NaN
# 60281  ENSG00000281548.1    0.380248   0.817758  1.810211   0.451747
# 60380  ENSG00000281778.1    0.000000        NaN       NaN        NaN
# 60399  ENSG00000281832.1    0.467860   2.465883  1.607466   1.534019
#
#               p-val     p-val adj       Name
# 122    1.213339e-24  3.620979e-22  LINC01007
# 169    1.241694e-22  2.681110e-20  LINC02217
# ...

# %%
df24 = df19[df19['p-val adj'] < 0.05]
#all significant features

# %%
df24
# Out:
#           Ensembl Gene ID     baseMean    Log2FC     lfcSE       stat  \
# 0       ENSG00000213553.4  1646.793666 -6.383591  0.374046 -17.066346
# 1       ENSG00000181104.6  2963.938005 -4.607920  0.275648 -16.716657
# 2       ENSG00000224861.1   208.653073 -4.792579  0.302110 -15.863674
# 3       ENSG00000198944.5  1555.586207  5.008116  0.318763  15.711106
# 4       ENSG00000169213.6  1350.561444  5.562841  0.364767  15.250387
# ...                   ...          ...       ...       ...        ...
# 13956   ENSG00000223459.5    75.502029  1.339871  0.571250   2.345507
# 13957   ENSG00000229162.1     1.531726 -3.004035  1.280751  -2.345526
# 13958  ENSG00000095951.15   865.579149  0.786394  0.335282   2.345466
# 13959   ENSG00000257261.4    64.627545 -1.057505  0.450893  -2.345357
# 13960   ENSG00000230756.1     3.682253 -1.827452  0.779199  -2.345295
#
#               p-val     p-val adj        Name
# 0      2.642298e-65  9.699084e-61     RPLP0P6
# ...

# %%
df25 = df24[~df24['Name'].str.contains('LINC')]

# %%
df25
#significant features not including lncRNAs
# Out:
#           Ensembl Gene ID     baseMean    Log2FC     lfcSE       stat  \
# 0       ENSG00000213553.4  1646.793666 -6.383591  0.374046 -17.066346
# 1       ENSG00000181104.6  2963.938005 -4.607920  0.275648 -16.716657
# 2       ENSG00000224861.1   208.653073 -4.792579  0.302110 -15.863674
# 3       ENSG00000198944.5  1555.586207  5.008116  0.318763  15.711106
# 4       ENSG00000169213.6  1350.561444  5.562841  0.364767  15.250387
# ...                   ...          ...       ...       ...        ...
# 13956   ENSG00000223459.5    75.502029  1.339871  0.571250   2.345507
# 13957   ENSG00000229162.1     1.531726 -3.004035  1.280751  -2.345526
# 13958  ENSG00000095951.15   865.579149  0.786394  0.335282   2.345466
# 13959   ENSG00000257261.4    64.627545 -1.057505  0.450893  -2.345357
# 13960   ENSG00000230756.1     3.682253 -1.827452  0.779199  -2.345295
#
#               p-val     p-val adj        Name
# 0      2.642298e-65  9.699084e-61     RPLP0P6
# ...

# %%
#significant non-lncRNAs sorted by Log2FC
df25 = df25.sort_values('Log2FC')

# %%
df28 = df25[['Name','p-val','Log2FC']].copy()

# %%
df25.head(15)
# Out:
#          Ensembl Gene ID     baseMean    Log2FC     lfcSE      stat  \
# 914    ENSG00000183072.9   101.882027 -9.106929  1.224319 -7.438363
# 789    ENSG00000128710.5    61.808269 -8.961590  1.167819 -7.673785
# 982    ENSG00000237380.5    59.681479 -8.910726  1.217210 -7.320612
# 2060   ENSG00000124102.4  1095.248701 -8.765216  1.466894 -5.975359
# 1599  ENSG00000105997.21   117.506653 -8.735204  1.350863 -6.466388
# 1242   ENSG00000005073.5    49.487793 -8.641707  1.247442 -6.927540
# 2877   ENSG00000257017.7   420.910855 -8.598385  1.599636 -5.375214
# 1109   ENSG00000106004.4   156.414591 -8.572790  1.202941 -7.126524
# 930    ENSG00000175879.8   211.704727 -8.556668  1.154221 -7.413370
# 1803   ENSG00000180818.4   156.417188 -8.513847  1.363883 -6.242357
# 1239  ENSG00000134028.13    66.169369 -8.482144  1.223686 -6.931633
# 2119   ENSG00000122592.7    65.123357 -8.461536  1.426531 -5.931547
# 284   ENSG00000168779.18   421.204075 -8.422205  0.922763 -9.127156
# ...

# %%
df28.head(15)
# Out:
#           Name         p-val    Log2FC
# 914     NKX2-5  1.019410e-13 -9.106929
# 789     HOXD10  1.669944e-14 -8.961590
# 982   HOXD-AS2  2.468421e-13 -8.910726
# 2060       PI3  2.295834e-09 -8.765216
# 1599     HOXA3  1.003734e-10 -8.735204
# 1242    HOXA11  4.282219e-12 -8.641707
# 2877        HP  7.649190e-08 -8.598385
# 1109     HOXA5  1.029352e-12 -8.572790
# 930      HOXD8  1.231301e-13 -8.556668
# 1803    HOXC10  4.310251e-10 -8.513847
# 1239  ADAMDEC1  4.160086e-12 -8.482144
# 2119     HOXA7  3.000935e-09 -8.461536
# 284      SHOX2  7.032256e-20 -8.422205
# 809     HOXA10  2.437444e-14 -8.296381
# 2449     HOXA4  1.621936e-08 -8.183074

# %%
df28.tail(15)
# Out:
#             Name         p-val    Log2FC
# 6932  AC008568.2  1.760358e-04  7.212086
# 71         PNMA5  3.102525e-27  7.225864
# 219       PNMA6F  3.549989e-21  7.281845
# 277        CNGB1  5.445948e-20  7.384820
# 267   AC073525.1  4.145745e-20  7.413944
# 1588      GSG1L2  9.057403e-11  7.422705
# 518         KLK7  6.224002e-17  7.520119
# 86       NEUROD6  2.427031e-26  7.523678
# 196      CD177P1  9.785239e-22  7.609726
# 558       OR14I1  1.812844e-16  7.641288
# 397         KLK5  1.944152e-18  7.761717
# 339   AC007922.3  4.617729e-19  7.960334
# 864      SLC22A8  5.240161e-14  8.024735
# 181   AP005242.4  3.757403e-22  8.120019
# 601     Z68323.1  4.600075e-16  8.541284

# %%
df21.loc[df21['name'] == 'KLHL1']
# Out:
#        initial_alias  converted_alias   name  \
# 349  ENSG00000150361  ENSG00000150361  KLHL1
#
#                                            description          namespace
# 349  kelch like family member 1 [Source:HGNC Symbol...  ARRAYEXPRESS,ENSG

# %%
df21
# Out:
#          initial_alias  converted_alias     name  \
# 0      ENSG00000213553  ENSG00000213553  RPLP0P6
# 1      ENSG00000181104  ENSG00000181104      F2R
# 2      ENSG00000224861  ENSG00000224861   YBX1P1
# 3      ENSG00000198944  ENSG00000198944   SOWAHA
# 4      ENSG00000169213  ENSG00000169213    RAB3B
# ...                ...              ...      ...
# 60478  ENSGR0000275287             None     None
# 60479  ENSGR0000276543             None     None
# 60480  ENSGR0000277120             None     None
# 60481  ENSGR0000280767             None     None
# 60482  ENSGR0000281849             None     None
#
#                                              description          namespace
# 0      ribosomal protein lateral stalk subunit P0 pse...  ARRAYEXPRESS,ENSG
# 1      coagulation factor II thrombin receptor [Sourc...  ARRAYEXPRESS,ENSG
# 2      Y-box binding protein 1 pseudogene 1 [Source:H...  ARRAYEXPRESS,ENSG
# ...

# %%
df23 = df22[df22['p-val adj'] < 0.05]

# %%
df23
#lncRNAs with p-value < 0.05
# Out:
#          Ensembl Gene ID    baseMean     Log2FC     lfcSE       stat  \
# 122    ENSG00000233123.1  172.510434  10.048779  0.980599  10.247588
# 169    ENSG00000248455.4   42.451333   6.082820  0.621323   9.790103
# 203    ENSG00000265313.4   40.004482   8.481965  0.888955   9.541506
# 253    ENSG00000206187.3   29.249152   7.743794  0.837701   9.244100
# 274    ENSG00000261325.1   21.631658   6.226237  0.679233   9.166574
# ...                  ...         ...        ...       ...        ...
# 13856  ENSG00000203930.9  168.697202   2.041860  0.865037   2.360430
# 13887  ENSG00000258586.1   12.059278  -2.898013  1.230492  -2.355166
# 13910  ENSG00000231768.1  329.320449  -1.235880  0.525429  -2.352137
# 13912  ENSG00000233237.5   89.970632  -0.953019  0.405213  -2.351893
# 13921  ENSG00000230040.1    4.578072  -4.022685  1.711298  -2.350662
#
#               p-val     p-val adj       Name
# 122    1.213339e-24  3.620979e-22  LINC01007
# 169    1.241694e-22  2.681110e-20  LINC02217
# ...

# %%
df23  = df23.sort_values('Log2FC')
#significant lncRNAs sorted by Log2FC

# %%
df25[df25['Ensembl Gene ID'].str.contains('ENSG00000225110')]
# Out:
#        Ensembl Gene ID    baseMean    Log2FC     lfcSE     stat         p-val  \
# 219  ENSG00000225110.1  278.394243  7.281845  0.770964  9.44512  3.549989e-21
#
#         p-val adj    Name
# 219  5.923157e-19  PNMA6F

# %%
df27 = df23[['Name','p-val','Log2FC']].copy()

# %%
df23.tail(15)
# Out:
#         Ensembl Gene ID    baseMean     Log2FC     lfcSE       stat  \
# 1780  ENSG00000253734.1    6.458752   6.119048  0.976070   6.269068
# 2635  ENSG00000237667.4    8.171005   6.154223  1.115441   5.517298
# 1748  ENSG00000230133.1    5.592155   6.216836  0.986101   6.304462
# 274   ENSG00000261325.1   21.631658   6.226237  0.679233   9.166574
# 1052  ENSG00000236922.8   18.127092   6.253969  0.866505   7.217463
# 940   ENSG00000280776.1   51.512679   6.280799  0.850393   7.385764
# 2696  ENSG00000237880.1    6.128899   6.348811  1.159869   5.473729
# 485   ENSG00000261340.1   98.447307   6.429289  0.759990   8.459705
# 1772  ENSG00000234111.5    5.809194   6.573490  1.046786   6.279686
# 527   ENSG00000228971.2  338.290646   6.711099  0.805632   8.330230
# 841   ENSG00000205634.5   12.961269   7.140142  0.944871   7.556741
# 521   ENSG00000225539.4   14.431603   7.591149  0.909421   8.347232
# 253   ENSG00000206187.3   29.249152   7.743794  0.837701   9.244100
# ...

# %%
df27.head(15)
# Out:
#             Name         p-val    Log2FC
# 335    LINC02732  3.475902e-19 -9.959702
# 1653   LINC02308  1.507156e-10 -6.922861
# 4133   LINC01385  2.223202e-06 -6.763381
# 3322   LINC01587  2.917424e-07 -6.624436
# 3743   LINC01571  8.961031e-07 -6.271130
# 4532   LINC01349  5.038460e-06 -5.550124
# 12658  LINC00458  1.109774e-02 -5.466004
# 4760   LINC02207  7.721452e-06 -5.438886
# 8586   LINC00466  8.287393e-04 -5.387265
# 5496   LINC01956  2.506566e-05 -5.246069
# 9617   LINC02783  1.945538e-03 -5.154953
# 2780   LINC02266  5.635535e-08 -4.863548
# 10183  LINC02620  2.887625e-03 -4.855705
# 7881   LINC01111  4.617255e-04 -4.848148
# 10467  LINC01142  3.433635e-03 -4.819756

# %%
df27.tail(15)
# Out:
#            Name         p-val     Log2FC
# 1780  LINC01289  3.632165e-10   6.119048
# 2635  LINC01115  3.442506e-08   6.154223
# 1748  LINC01721  2.891964e-10   6.216836
# 274   LINC02192  4.882904e-20   6.226237
# 1052  LINC01378  5.296621e-13   6.253969
# 940   LINC01202  1.515805e-13   6.280799
# 2696  LINC01885  4.406627e-08   6.348811
# 485   LINC01616  2.680558e-17   6.429289
# 1772  LINC02433  3.392568e-10   6.573490
# 527   LINC02607  8.068514e-17   6.711099
# 841   LINC00898  4.132941e-14   7.140142
# 521   LINC01821  6.988141e-17   7.591149
# 253   LINC02346  2.372281e-20   7.743794
# 203   LINC01476  1.407724e-21   8.481965
# 122   LINC01007  1.213339e-24  10.048779

# %%
df22.dropna()
# Out:
#          Ensembl Gene ID    baseMean     Log2FC     lfcSE       stat  \
# 122    ENSG00000233123.1  172.510434  10.048779  0.980599  10.247588
# 169    ENSG00000248455.4   42.451333   6.082820  0.621323   9.790103
# 203    ENSG00000265313.4   40.004482   8.481965  0.888955   9.541506
# 253    ENSG00000206187.3   29.249152   7.743794  0.837701   9.244100
# 274    ENSG00000261325.1   21.631658   6.226237  0.679233   9.166574
# ...                  ...         ...        ...       ...        ...
# 36541  ENSG00000205106.4   66.538207  -0.010694  0.771454  -0.013862
# 36576  ENSG00000224977.1    2.359572  -0.008655  0.772059  -0.011210
# 36602  ENSG00000258474.1    0.790449  -0.010909  1.201453  -0.009080
# 36619  ENSG00000266904.4  247.703014  -0.002107  0.274784  -0.007669
# 36658  ENSG00000238042.4    0.620044  -0.006633  1.470592  -0.004511
#
#               p-val     p-val adj       Name
# 122    1.213339e-24  3.620979e-22  LINC01007
# 169    1.241694e-22  2.681110e-20  LINC02217
# ...

# %%
df19["log10(p-val)"] = np.log10(df19["p-val"])

# %%
df19['-log10(p-val)'] = df19['log10(p-val)'].abs()

# %%
figure_presets(
    title="Volcano Plot",
    x_lab="Log\u2082 (Fold-change)",  # the prefix "\u208" before a number will create a subscript of that number
    y_lab="-Log10 (p-value)",
)

plt.scatter(df19["Log2FC"], df19["-log10(p-val)"], c="lightgray", alpha=0.5)

plt.axhline(y= 1.30102999566, linewidth=2.5, color='black', linestyle='--', alpha=0.75)
plt.axvline(x= -2, lw=2.5, color='black', linestyle='--', alpha=0.75)
plt.axvline(x= 2, lw=2.5, color='black', linestyle='--', alpha=0.75)

plt.grid(color='grey', linestyle='-', linewidth=0.5, alpha=0.5)

# %%
df26 = df19[df19['-log10(p-val)'] > 49]

# %%
df19[df19['-log10(p-val)'] > 38]
# Out:
#      Ensembl Gene ID      baseMean    Log2FC     lfcSE       stat  \
# 0  ENSG00000213553.4   1646.793666 -6.383591  0.374046 -17.066346
# 1  ENSG00000181104.6   2963.938005 -4.607920  0.275648 -16.716657
# 2  ENSG00000224861.1    208.653073 -4.792579  0.302110 -15.863674
# 3  ENSG00000198944.5   1555.586207  5.008116  0.318763  15.711106
# 4  ENSG00000169213.6   1350.561444  5.562841  0.364767  15.250387
# 5  ENSG00000213763.4    168.126781 -4.739522  0.316781 -14.961504
# 6  ENSG00000100884.8   3880.861105  6.025329  0.459572  13.110730
# 7  ENSG00000220205.7  19118.399936  2.801054  0.214047  13.086188
# 8  ENSG00000162456.8     44.387226  6.716573  0.515597  13.026799
#
#           p-val     p-val adj     Name  log10(p-val)  -log10(p-val)
# 0  2.642298e-65  9.699084e-61  RPLP0P6    -64.578018      64.578018
# 1  9.912533e-63  1.819297e-58      F2R    -62.003815      62.003815
# 2  1.130812e-56  1.383624e-52   YBX1P1    -55.946610      55.946610
# ...

# %%
df19.to_csv(r'/Users/vedadayananda/Downloads/lncRNA Project/df19.csv', index = False, header =True)

# %%
def figure_presets_temp(
    title,
    x_lab,
    y_lab,
    size=(10, 10),
    title_fontsize=20,
    title_adjustment_factor=1.1,
    axis_label_fontsize=15,
):

    """
    presets for one single figure to look nice
    """

    fig = plt.figure(figsize=size)
    ax = fig.add_subplot(1, 1, 1)
    ax.set_title(title, fontsize=title_fontsize, y=title_adjustment_factor)
    ax.set_xlabel(x_lab, fontsize=axis_label_fontsize)
    ax.set_ylabel(y_lab, fontsize=axis_label_fontsize)
    ax.spines["left"].set_linewidth(3)
    ax.spines["bottom"].set_linewidth(3)
    #removing top and right borders
    ax.spines["right"].set_visible(False)
    ax.spines["top"].set_visible(False)
    ax.yaxis.set_ticks_position("left")
    ax.xaxis.set_ticks_position("bottom")
    return ax

# %%
import matplotlib
import scipy.stats as stats

def qqplot(pval, pval_null=None, title='', labels=None, ax=None, c=None, s=16):
    ax = figure_presets_temp(
        title="Q-Q Plot",
        x_lab="Expected -log$\mathregular{_{10}}$(p-value)",  # the prefix "\u208" before a number will create a subscript of that number
        y_lab="Observed -log$\mathregular{_{10}}$(p-value)")
    """QQ-plot"""
    
    if labels is None:
        labels = ['', '']
    n = len(pval)
    x = -np.log10(np.arange(1,n+1)/(n+1))
    if ax is None:
        fig, ax = plt.subplots()
    ax.margins(x=0.02, y=0.05)
    args = {'s':s, 'edgecolor':'none', 'clip_on':False, 'alpha':1, 'rasterized':True}
    log_pval_sorted = -np.log10(np.sort(pval))
    ax.scatter(
        x,
        log_pval_sorted,
        c=c,
        zorder=30,
        label=labels[0],
        **args
    )
    if pval_null is not None:
        assert len(pval)==len(pval_null)
        log_pval_sorted = -np.log10(np.sort(pval_null))
        ax.scatter(
            x,
            log_pval_sorted,
            c=[[0.5]*3],
            zorder=20,
            label=labels[1],
            **args
        )
    ax.xaxis.set_major_locator(matplotlib.ticker.MaxNLocator(integer=True, min_n_ticks=5, nbins=4))
    ax.yaxis.set_major_locator(matplotlib.ticker.MaxNLocator(integer=True, min_n_ticks=5, nbins=4))
    ax.set_xlabel('Expected -log$\mathregular{_{10}}$(p-value)', fontsize=14)
    ax.set_ylabel('Observed -log$\mathregular{_{10}}$(p-value)', fontsize=14)
    xlim = ax.get_xlim()
    ylim = ax.get_ylim()
    ax.set_xlim([0, xlim[1]])
    ax.set_ylim([0, ylim[1]])
    ci = 0.95
    xi = np.arange(1, n+1)
    clower = -np.log10(stats.beta.ppf((1-ci)/2, xi, xi[::-1]))
    cupper = -np.log10(stats.beta.ppf((1+ci)/2, xi, xi[::-1]))
    ax.fill_between(x, cupper, clower, color=[[0.8]*3], clip_on=True, rasterized=True)
    ax.plot([x[0], x[-1]], [x[0], x[-1]], '--', lw=1, color=[0.2]*3, zorder=50, clip_on=True, rasterized=True)
    #ax.spines['left'].set_position(('outward', 6))
    #ax.spines['bottom'].set_position(('outward', 6))
    title = 'Q-Q Plot'
    ax.set_title('{}'.format(title), fontsize=12)
    if labels[0] != '':
        ax.legend(loc='upper left', fontsize=10, handlelength=0.5, handletextpad=0.33)

# %%
qqplot(df19['p-val'])

# %%
df19
# Out:
#          Ensembl Gene ID     baseMean    Log2FC     lfcSE       stat  \
# 0      ENSG00000213553.4  1646.793666 -6.383591  0.374046 -17.066346
# 1      ENSG00000181104.6  2963.938005 -4.607920  0.275648 -16.716657
# 2      ENSG00000224861.1   208.653073 -4.792579  0.302110 -15.863674
# 3      ENSG00000198944.5  1555.586207  5.008116  0.318763  15.711106
# 4      ENSG00000169213.6  1350.561444  5.562841  0.364767  15.250387
# ...                  ...          ...       ...       ...        ...
# 60478  ENSGR0000275287.3     0.000000       NaN       NaN        NaN
# 60479  ENSGR0000276543.3     0.000000       NaN       NaN        NaN
# 60480  ENSGR0000277120.3     0.000000       NaN       NaN        NaN
# 60481  ENSGR0000280767.1     0.000000       NaN       NaN        NaN
# 60482  ENSGR0000281849.1     0.000000       NaN       NaN        NaN
#
#               p-val     p-val adj     Name  log10(p-val)  -log10(p-val)
# ...

# %%
df19.to_csv('/Users/vedadayananda/Downloads/lncRNA Project/p-vaules.csv',sep=' ', index = False, header =True)

# %%
from gtfparse import read_gtf

# %%
gtf = read_gtf("/Users/vedadayananda/Downloads/gencode.v19.annotation.gtf")
# Out:
# INFO:root:Extracted GTF attributes: ['gene_id', 'transcript_id', 'gene_type', 'gene_status', 'gene_name', 'transcript_type', 'transcript_status', 'transcript_name', 'level', 'havana_gene', 'tag', 'havana_transcript', 'exon_number', 'exon_id', 'ont', 'protein_id', 'ccdsid']

# %%
gtf['midpt'] = (gtf['start'] + gtf['end'])/2

# %%
gtf
# Out:
#         seqname   source     feature  start    end  score strand frame  \
# 0          chr1   HAVANA        gene  11869  14412    NaN      +     0
# 1          chr1   HAVANA  transcript  11869  14409    NaN      +     0
# 2          chr1   HAVANA        exon  11869  12227    NaN      +     0
# 3          chr1   HAVANA        exon  12613  12721    NaN      +     0
# 4          chr1   HAVANA        exon  13221  14409    NaN      +     0
# ...         ...      ...         ...    ...    ...    ...    ...   ...
# 2619439    chrM  ENSEMBL  transcript  15888  15953    NaN      +     0
# 2619440    chrM  ENSEMBL        exon  15888  15953    NaN      +     0
# 2619441    chrM  ENSEMBL        gene  15956  16023    NaN      -     0
# 2619442    chrM  ENSEMBL  transcript  15956  16023    NaN      -     0
# 2619443    chrM  ENSEMBL        exon  15956  16023    NaN      -     0
#
#                    gene_id      transcript_id  ... level  \
# ...

# %%
gtf[gtf['transcript_name'].str.contains('LINC01202')]
# Out:
# Empty DataFrame
# Columns: [seqname, source, feature, start, end, score, strand, frame, gene_id, transcript_id, gene_type, gene_status, gene_name, transcript_type, transcript_status, transcript_name, level, havana_gene, tag, havana_transcript, exon_number, exon_id, ont, protein_id, ccdsid, midpt]
# Index: []
#
# [0 rows x 26 columns]

# %%
gtf.loc[2600703,'transcript_name']
# Out:
# 'LL0XNC01-16G2.1'

# %%
import pandas as pd

data = pd.read_excel('/Users/vedadayananda/Downloads/test.xlsx')
df29 = pd.DataFrame(data, columns = ['Column1','Column2','Column3','Column4'])

df29.head()
# Out:
#   Column1  Column2  Column3  Column4
# 0       A      NaN      NaN      NaN
# 1       D      NaN      NaN      NaN
# 2       G      NaN      NaN      NaN
# 3       J      NaN      NaN      NaN
# 4       M      NaN      NaN      NaN

# %%
newgtf = read_gtf("/Users/vedadayananda/Downloads/lncRNA Project/gencode.v22.annotation.gtf")
# Out:
# INFO:root:Extracted GTF attributes: ['gene_id', 'gene_type', 'gene_status', 'gene_name', 'level', 'havana_gene', 'transcript_id', 'transcript_type', 'transcript_status', 'transcript_name', 'tag', 'transcript_support_level', 'havana_transcript', 'exon_number', 'exon_id', 'ont', 'protein_id', 'ccdsid']

# %%
newgtf['midpt'] = (newgtf['start'] + newgtf['end'])/2

# %%
newgtf
# Out:
#         seqname   source     feature  start    end  score strand frame  \
# 0          chr1   HAVANA        gene  11869  14409    NaN      +     0
# 1          chr1   HAVANA  transcript  11869  14409    NaN      +     0
# 2          chr1   HAVANA        exon  11869  12227    NaN      +     0
# 3          chr1   HAVANA        exon  12613  12721    NaN      +     0
# 4          chr1   HAVANA        exon  13221  14409    NaN      +     0
# ...         ...      ...         ...    ...    ...    ...    ...   ...
# 2563666    chrM  ENSEMBL  transcript  15888  15953    NaN      +     0
# 2563667    chrM  ENSEMBL        exon  15888  15953    NaN      +     0
# 2563668    chrM  ENSEMBL        gene  15956  16023    NaN      -     0
# 2563669    chrM  ENSEMBL  transcript  15956  16023    NaN      -     0
# 2563670    chrM  ENSEMBL        exon  15956  16023    NaN      -     0
#
#                    gene_id                           gene_type  ...  \
# ...

# %%
newgtf[newgtf['gene_id'].str.contains('ENSG00000205634.5')]
# Out:
#         seqname  source     feature     start       end  score strand frame  \
# 2470191   chr22  HAVANA        gene  47621043  47631569    NaN      -     0
# 2470192   chr22  HAVANA  transcript  47621043  47631569    NaN      -     0
# 2470193   chr22  HAVANA        exon  47629328  47631569    NaN      -     0
# 2470194   chr22  HAVANA        exon  47627438  47627577    NaN      -     0
# 2470195   chr22  HAVANA        exon  47627162  47627242    NaN      -     0
# 2470196   chr22  HAVANA        exon  47624468  47625633    NaN      -     0
# 2470197   chr22  HAVANA        exon  47622456  47622952    NaN      -     0
# 2470198   chr22  HAVANA        exon  47621043  47621101    NaN      -     0
# 2470199   chr22  HAVANA  transcript  47625230  47629902    NaN      -     0
# 2470200   chr22  HAVANA        exon  47629328  47629902    NaN      -     0
# 2470201   chr22  HAVANA        exon  47627309  47627577    NaN      -     0
# ...

# %%
df19.loc[df19['Name'] == 'LINC00898']
# Out:
#        Ensembl Gene ID   baseMean    Log2FC     lfcSE      stat         p-val  \
# 841  ENSG00000205634.5  12.961269  7.140142  0.944871  7.556741  4.132941e-14
#
#         p-val adj       Name  log10(p-val)  -log10(p-val)
# 841  1.801756e-12  LINC00898    -13.383741      13.383741

# %%
df19[df19['Name'].str.contains('NF1')]
# Out:
#           Ensembl Gene ID     baseMean    Log2FC     lfcSE      stat  \
# 733     ENSG00000237758.1    39.640377 -3.380102  0.433198 -7.802678
# 2197   ENSG00000181481.12   729.394177 -1.992707  0.339610 -5.867632
# 3350   ENSG00000173918.13  3171.042602 -3.303941  0.645558 -5.117961
# 3606    ENSG00000228203.5   244.568419  4.082797  0.818650  4.987234
# 4943    ENSG00000133874.1   577.544951 -2.145847  0.487322 -4.403350
# ...                   ...          ...       ...       ...       ...
# 56593   ENSG00000271194.1     0.000000       NaN       NaN       NaN
# 58663   ENSG00000277529.1     0.000000       NaN       NaN       NaN
# 58934   ENSG00000278143.1     0.000000       NaN       NaN       NaN
# 58949   ENSG00000278184.1     0.049624 -0.270485  3.258026 -0.083021
# 60204   ENSG00000281347.1     0.000000       NaN       NaN       NaN
#
#               p-val     p-val adj         Name  log10(p-val)  -log10(p-val)
# ...

# %%
import pandas as pd

df30 = pd.read_excel (r'/Users/vedadayananda/Downloads/lncRNA Project/distance.xlsx')

# %%
df30["distance"] = abs(df30["gene midpt"] - df30["lncrna midpt"])

# %%
df30.sort_values("distance")
# Out:
#     chr      gene     lncrna   gene midpt  lncrna midpt     distance
# 59   17   RPS6KB1  LINC01476   59921805.0    59478907.5     442897.5
# 8     1      MTOR  LINC02783   11184521.0    17193700.0    6009179.0
# 53   16     CNGB1  LINC01571   57926728.0    51767846.0    6158882.0
# 52   16     CNGB1  LINC02192   57926728.0    47868222.0   10058506.0
# 32    5    NKX2-5  LINC01202  173233733.0   161955724.0   11278009.0
# ..  ...       ...        ...          ...           ...          ...
# 16    2  HOXD-AS2  LINC01115  176129354.5      824133.0  175305221.5
# 20    2     HOXD8  LINC01115  176131194.5      824133.0  175307061.5
# 28    4      LKB1  LINC01587  186233725.0     5526185.0  180707540.0
# 2     1    OR14I1  LINC00466  248681836.5    63253610.0  185428226.5
# 3     1    OR14I1  LINC02783  248681836.5    17193700.0  231488136.5
#
# [63 rows x 6 columns]

# %%
df31 = pd.read_excel (r'/Users/vedadayananda/Downloads/lncRNA Project/distanceFC.xlsx')

# %%
df31["Distance"] = abs(df31["Gene midpt"] - df31["lncRNA midpt"])

# %%
pd.set_option('display.max_rows', None)
df31.sort_values("Distance")
# Out:
#     Chromosome        Gene     lncRNA   Gene midpt  lncRNA midpt  Gene logFC  \
# 59          17     RPS6KB1  LINC01476   59921805.0    59478907.5    0.127054
# 8            1        MTOR  LINC02783   11184521.0    17193700.0    0.893706
# 53          16       CNGB1  LINC01571   57926728.0    51767846.0    7.384820
# 52          16       CNGB1  LINC02192   57926728.0    47868222.0    7.384820
# 32           5      NKX2-5  LINC01202  173233733.0   161955724.0   -9.106929
# 62          22    Z68323.1  LINC00898   34208701.5    47626306.0    8.541284
# 48          10        PTEN  LINC02620   87917521.5   104477606.5    0.751280
# 19           2       HOXD8  LINC01821  176131194.5   194381957.0   -8.556668
# 15           2    HOXD-AS2  LINC01821  176129354.5   194381957.0   -8.910726
# 11           2      HOXD10  LINC01821  176114366.0   194381957.0   -8.961590
# 55          16          HP  LINC01571   72057823.5    51767846.0   -8.598385
# ...
